# %% [markdown]
# <a href="https://colab.research.google.com/github/Tejasgvr/Tejas/blob/main/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## **Python code for text handling**

# %% [markdown]
# ## Palindrome word

# %%
def is_palindrome(word):
    word = word.lower()
    return word == word[::-1]
word = input("Enter a word: ")
if is_palindrome(word):
    print(f"'{word}' is a palindrome.")
else:
    print(f"'{word}' is not a palindrome.")
# Out:
# Enter a word: level
# 'level' is a palindrome.

# %% [markdown]
# ## **Python code for file handling**

# %% [markdown]
# Code to read data from txt file

# %%
with open('tejas.txt', 'r') as file:
    for line in file:
        print(line.strip())
# Out:
# hello google Collab
# have a great day

# %% [markdown]
# ## **Python code for image processing**

# %% [markdown]
# ### To display the image

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Load the image from file
img = mpimg.imread('tejasimage.webp')  # Replace with your image file name

# Display the image
plt.imshow(img)
plt.axis('off')  # Hide axes for cleaner look
plt.show()

# %% [markdown]
# ### **Python code for handling video files**

# %% [markdown]
# code to read and play a video

# %%
from google.colab import files
from IPython.display import HTML
from base64 import b64encode

uploaded = files.upload()
video_path = list(uploaded.keys())[0]
video_file = open(video_path, "rb").read()
video_url = f"data:video/mp4;base64,{b64encode(video_file).decode()}"
HTML(f'<video width="600" controls><source src="{video_url}" type="video/mp4"></video>')
# Out:
#      <input type="file" id="files-8c63e94b-48a4-46a0-b4f4-1cc382ca5885" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8c63e94b-48a4-46a0-b4f4-1cc382ca5885">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...
